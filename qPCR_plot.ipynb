# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
from scipy import stats

# %%
from qPCR import qPCR_plot
qPCR_plot(sort_by="folds_asc")
# Out:
# Enter name of ref gene in ./data\Data1.csv: Ref
# Enter name of control group in ./data\Data1.csv: Ctrl
# C:\Users\kouda\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# Enter name of ref gene in ./data\Data2.csv: Ref
# Enter name of control group in ./data\Data2.csv: Ctrl
# Enter name of ref gene in ./data\Data3.csv: Ref
# Enter name of control group in ./data\Data3.csv: Ctrl
# Enter name of ref gene in ./data\Data4.csv: Ref
# Enter name of control group in ./data\Data4.csv: Ctrl
